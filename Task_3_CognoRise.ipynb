# %% [markdown]
# <a href="https://colab.research.google.com/github/ShibuGitB/CognoRise_InfoTech/blob/main/Task_3_CognoRise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing Necessary Packages***

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,classification_report

# %% [markdown]
# ***Dataset***

# %%
dataset=pd.read_csv("/content/drive/MyDrive/Task 3 CognoRise/data.csv")
dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ***Checking all values are numeric or not***

# %%
dataset.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# ***Converting string values to numeric***

# %%
dataset["diagnosis"]=dataset["diagnosis"].map({"M":1,"B":2})

# %%
dataset
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          2         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# ***Checking Corrulation to drop unwanted columns***

# %%
dataset.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000  -0.039769     0.074626      0.099770
# diagnosis               -0.039769   1.000000    -0.730029     -0.415185
# radius_mean              0.074626  -0.730029     1.000000      0.323782
# texture_mean             0.099770  -0.415185     0.323782      1.000000
# perimeter_mean           0.073159  -0.742636     0.997855      0.329533
# area_mean                0.096893  -0.708984     0.987357      0.321086
# smoothness_mean         -0.012968  -0.358560     0.170581     -0.023389
# compactness_mean         0.000096  -0.596534     0.506124      0.236702
# concavity_mean           0.050080  -0.696360     0.676764      0.302418
# concave points_mean      0.044158  -0.776614     0.822529      0.293464
# symmetry_mean           -0.022114  -0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511   0.012838    -0.311631     -0.076437
# ...

# %% [markdown]
# ***Droping unwanted columns***

# %%
columns=["id","fractal_dimension_mean","texture_se","smoothness_se","symmetry_se","fractal_dimension_se","Unnamed: 32"]

for i in columns :

  dataset.drop([i],axis=1,inplace=True)

# %%
dataset
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          2         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
dataset.dtypes
# Out:
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# radius_se                  float64
# perimeter_se               float64
# area_se                    float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %% [markdown]
# ***Checking is there any missing values or not***

# %%
dataset.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# radius_se                  0
# perimeter_se               0
# area_se                    0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ***seperating input and output***

# %%
input=dataset.iloc[:,1:]
output=dataset.iloc[:,0]

# %% [markdown]
# ***Scaling input & output***

# %%
scaler=MinMaxScaler()
scaler.fit(input)
input=scaler.transform(input)

# %% [markdown]
# ***Taking input & output for training & testing***

# %%
x_train,x_test,y_train,y_test=train_test_split(input,output,test_size=0.3,random_state=1)

# %% [markdown]
# ***Applying all algorithms and making models and checking their accuracys***

# %%
model1=KNeighborsClassifier(n_neighbors=7)
model1.fit(x_train,y_train)
y_pred1=model1.predict(x_test)

# %%
print (accuracy_score(y_test,y_pred1))
# Out:
# 0.9649122807017544

# %%
model3=GaussianNB()
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)

# %%
print (accuracy_score(y_test,y_pred3))
# Out:
# 0.935672514619883

# %%
model4=DecisionTreeClassifier(criterion="entropy")
model4.fit(x_train,y_train)
y_pred4=model4.predict(x_test)

# %%
print (accuracy_score(y_test,y_pred4))
# Out:
# 0.8888888888888888

# %%
model5=RandomForestClassifier(n_estimators=200,criterion="entropy")
model5.fit(x_train,y_train)
y_pred5=model5.predict(x_test)

# %%
print (accuracy_score(y_test,y_pred5))
# Out:
# 0.9590643274853801

# %%
model6=AdaBoostClassifier()
model6.fit(x_train,y_train)
y_pred6=model6.predict(x_test)

# %%
print (accuracy_score(y_test,y_pred6))
# Out:
# 0.9590643274853801

# %% [markdown]
# ***choosed a best model from support vector classifier with an almost accuracy of 97%***

# %%
model2=SVC(kernel="rbf")
model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)

# %%
print (accuracy_score(y_test,y_pred2))
# Out:
# 0.9707602339181286

# %%
print (ConfusionMatrixDisplay.from_predictions(y_test,y_pred2))

# %%
print (classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.98      0.94      0.96        63
#            2       0.96      0.99      0.98       108
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***Taking a prediction from a sample input***

# %%
prediction=model2.predict(scaler.transform([[17.99,10.38,122.80,1001.0,0.11840,0.27760,0.30010,0.14710,0.2419,25.380,17.33,184.60,2019.0,0.16220,0.66560,0.7119,0.2654,0.4601,0.11890,0.777,0.444,0.444,0.555,0.6666,0.777]]))

if prediction==1 :

  print ("malignant")

else :

  print ("benign")
# Out:
# malignant
