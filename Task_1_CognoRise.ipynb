# %% [markdown]
# <a href="https://colab.research.google.com/github/ShibuGitB/CognoRise_InfoTech/blob/main/Task_1_CognoRise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing Necessary Packages***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# ***Dataset***

# %%
dataset=pd.read_csv("/content/drive/MyDrive/Task 1 CognoRise/data.csv")
dataset
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %% [markdown]
# ***Droping Unwanted Columns***

# %%
dataset.drop(["date"],axis=1,inplace=True)

# %%
dataset.dtypes
# Out:
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %% [markdown]
# ***Converting String columns to Numeric value***

# %%
columns=["street","city"]

for i in columns :

  encoder=LabelEncoder()
  encoder.fit(dataset[i])
  dataset[i]=encoder.transform(dataset[i])

# %%
dataset
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
dataset["statezip"]=dataset["statezip"].str.replace("WA","")

# %%
dataset["statezip"]=dataset["statezip"].astype(float)

# %%
dataset["country"]=dataset["country"].map({"USA":1})

# %%
dataset.dtypes
# Out:
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street             int64
# city               int64
# statezip         float64
# country            int64
# dtype: object

# %% [markdown]
# ***Pre-Processed Dataset***

# %%
dataset
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
dataset.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# ***Seperating Input & Output***

# %%
input=dataset.iloc[:,1:]

# %%
output=dataset.iloc[:,0]

# %% [markdown]
# ***Taking input & output for the Training & Testing***

# %%
x_train,x_test,y_train,y_test=train_test_split(input,output,test_size=0.3,random_state=1)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***Applying algorithms and making models and checking accuracybto take a best model***

# %%
model1=LinearRegression(fit_intercept=True,copy_X=True,n_jobs=1,positive=True)
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)

# %%
print (r2_score(y_test,y_pred))
# Out:
# 0.4381090083949053

# %%
model2=DecisionTreeRegressor(criterion='squared_error', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, ccp_alpha=0.0)
model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)

# %%
print (r2_score(y_test,y_pred2))
# Out:
# -7.177618196905682

# %%
model3=RandomForestRegressor(n_estimators=100, criterion='squared_error', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=1.0, max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=1, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None)
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)

# %%
print (r2_score(y_test,y_pred3)*100)
# Out:
# 8.088897865263057

# %%
model4=AdaBoostRegressor(estimator=None,learning_rate=1.0,loss="linear",n_estimators=50,random_state=1)
model4.fit(x_train,y_train)
y_pred4=model4.predict(x_test)

# %%
print (r2_score(y_test,y_pred4))
# Out:
# 0.1881932902759187

# %%
model5=XGBRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)
model5.fit(x_train,y_train)
y_pred5=model5.predict(x_test)

# %%
print (r2_score(y_pred5,y_test))
# Out:
# 0.23604493041096708

# %%
model6=Lasso(alpha=1.0, fit_intercept=True, precompute=False, copy_X=True, max_iter=1000, tol=0.0001, warm_start=False, positive=False, random_state=None, selection='cyclic')
model6.fit(x_train,y_train)
y_pred6=model6.predict(x_test)

# %%
print (r2_score(y_test,y_pred6))
# Out:
# 0.4761750427117345

# %%
from sklearn.neighbors import KNeighborsRegressor
model8=KNeighborsRegressor(n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)
model8.fit(x_train,y_train)
y_pred8=model8.predict(x_test)

# %%
print (r2_score(y_test,y_pred8))
# Out:
# -0.3104253008832485

# %%
model7=Ridge(alpha=1.0, fit_intercept=True, copy_X=True, max_iter=None, tol=0.0001, solver='auto', positive=False, random_state=None)
model7.fit(x_train,y_train)
y_pred7=model7.predict(x_test)

# %%
print (r2_score(y_test,y_pred7))
# Out:
# 0.4778245608759558

# %% [markdown]
# ***Took Ridge Regression Model at almost accuracy of 47% ,corresponding to other models it would better***

# %% [markdown]
# ***Taking prediction by sample input***

# %%
prediction=model7.predict([[3.0,1.50,1340,7912,1.5,0,0,3,1340,0,1955,2005,1522,36,98133.0,1]])
print ("House Price by corresponding Details :-",prediction.item(),"Rs")
# Out:
# House Price by corresponding Details :- 372168.20980934054 Rs
